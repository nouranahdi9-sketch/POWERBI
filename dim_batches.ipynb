# %%
# %run ./transform_data

# %% [markdown]
# cette table doit contenir les informations suivantes :
# - batch_id
# - batch_number
# - prd_line
# - id_production_line
# - planned_date

# %%
dim_batches = batches_full_list

# %% [markdown]
# Ingestion des données dans la table cible

# %%
current_process= "dim_batches"

# %%
target_dim_batches = current_catalog +"."+current_schema+"."+current_process
print(target_dim_batches)

# %%
all_columns =  dim_batches.columns
display(all_columns)

# %%
# define the primary key 
primary_key = [    
    'id_batch']

additional_columns = get_additional_columns(all_columns, primary_key)

if verbose_mode == 'debug': 
    print(additional_columns)

# %%
handle_table_update(
    dim_batches, 
    target_dim_batches, 
    primary_key, 
    all_columns,
    additional_columns_to_check=additional_columns,
    mode=execution_mode # Use "update" for update mode, "full" for delete/insert mode
    )
