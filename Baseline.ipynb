# %%
import pandas as pd

# %%
# Importation des tables pour ROUEN1
rouen1 = 'C:/Users/probl/Documents/Invivo/Baseline/ROUEN1/Baseline ROUEN1.xlsx'
df_rouen1_indiv = pd.read_excel(rouen1, sheet_name='nb_individus')
df_rouen1_malt_yield_r2 = pd.read_excel(rouen1, sheet_name='malt_yield_r2')
df_rouen1_malt_dry_yield = pd.read_excel(rouen1, sheet_name='malt_dry_yield')
df_rouen1_goods_weight = pd.read_excel(rouen1, sheet_name='goods_weight')
df_rouen1_goods_moisture = pd.read_excel(rouen1, sheet_name='goods_moisture')
df_rouen1_malt_moisture = pd.read_excel(rouen1, sheet_name='malt_moisture')
df_rouen1_electricity = pd.read_excel(rouen1, sheet_name='electricity')
df_rouen1_thermal = pd.read_excel(rouen1, sheet_name='thermal')
df_rouen1_FAN = pd.read_excel(rouen1, sheet_name='FAN')
df_rouen1_fria = pd.read_excel(rouen1, sheet_name='friabilite')
df_rouen1_color_EBC = pd.read_excel(rouen1, sheet_name='coloration_EBC')
df_rouen1_betaG = pd.read_excel(rouen1, sheet_name='betaG')
df_rouen1_quality = pd.read_excel(rouen1, sheet_name='quality')

# %%
# Importation des tables pour NOGENT1
nogent1 = 'C:/Users/probl/Documents/Invivo/Baseline/NOGENT1/Baseline NOGENT1.xlsx'
df_nogent1_indiv = pd.read_excel(nogent1, sheet_name='nb_individus')
df_nogent1_malt_yield_r2 = pd.read_excel(nogent1, sheet_name='malt_yield_r2')
df_nogent1_malt_dry_yield = pd.read_excel(nogent1, sheet_name='malt_dry_yield')
df_nogent1_goods_weight = pd.read_excel(nogent1, sheet_name='goods_weight')
df_nogent1_goods_moisture = pd.read_excel(nogent1, sheet_name='goods_moisture')
df_nogent1_malt_moisture = pd.read_excel(nogent1, sheet_name='malt_moisture')
df_nogent1_electricity = pd.read_excel(nogent1, sheet_name='electricity')
df_nogent1_thermal = pd.read_excel(nogent1, sheet_name='thermal')
df_nogent1_FAN = pd.read_excel(nogent1, sheet_name='FAN')
df_nogent1_fria = pd.read_excel(nogent1, sheet_name='friabilite')
df_nogent1_color_EBC = pd.read_excel(nogent1, sheet_name='coloration_EBC')
df_nogent1_betaG = pd.read_excel(nogent1, sheet_name='betaG')
df_nogent1_quality = pd.read_excel(nogent1, sheet_name='quality')

# %%
# Importation des tables pour NOGENT2
nogent2 = 'C:/Users/probl/Documents/Invivo/Baseline/NOGENT2/Baseline NOGENT2.xlsx'
df_nogent2_indiv = pd.read_excel(nogent2, sheet_name='nb_individus')
df_nogent2_malt_yield_r2 = pd.read_excel(nogent2, sheet_name='malt_yield_r2')
df_nogent2_malt_dry_yield = pd.read_excel(nogent2, sheet_name='malt_dry_yield')
df_nogent2_goods_weight = pd.read_excel(nogent2, sheet_name='goods_weight')
df_nogent2_goods_moisture = pd.read_excel(nogent2, sheet_name='goods_moisture')
df_nogent2_malt_moisture = pd.read_excel(nogent2, sheet_name='malt_moisture')
df_nogent2_electricity = pd.read_excel(nogent2, sheet_name='electricity')
df_nogent2_thermal = pd.read_excel(nogent2, sheet_name='thermal')
df_nogent2_FAN = pd.read_excel(nogent2, sheet_name='FAN')
df_nogent2_fria = pd.read_excel(nogent2, sheet_name='friabilite')
df_nogent2_color_EBC = pd.read_excel(nogent2, sheet_name='coloration_EBC')
df_nogent2_betaG = pd.read_excel(nogent2, sheet_name='betaG')
df_nogent2_quality = pd.read_excel(nogent2, sheet_name='quality')

# %%
# Importation des tables pour POLISY1
polisy1 = 'C:/Users/probl/Documents/Invivo/Baseline/POLISY1/Baseline POLISY1.xlsx'
df_polisy1_indiv = pd.read_excel(polisy1, sheet_name='nb_individus')
df_polisy1_malt_yield_r2 = pd.read_excel(polisy1, sheet_name='malt_yield_r2')
df_polisy1_malt_dry_yield = pd.read_excel(polisy1, sheet_name='malt_dry_yield')
df_polisy1_goods_weight = pd.read_excel(polisy1, sheet_name='goods_weight')
df_polisy1_goods_moisture = pd.read_excel(polisy1, sheet_name='goods_moisture')
df_polisy1_malt_moisture = pd.read_excel(polisy1, sheet_name='malt_moisture')
df_polisy1_electricity = pd.read_excel(polisy1, sheet_name='electricity')
df_polisy1_thermal = pd.read_excel(polisy1, sheet_name='thermal')
df_polisy1_FAN = pd.read_excel(polisy1, sheet_name='FAN')
df_polisy1_fria = pd.read_excel(polisy1, sheet_name='friabilite')
df_polisy1_color_EBC = pd.read_excel(polisy1, sheet_name='coloration_EBC')
df_polisy1_betaG = pd.read_excel(polisy1, sheet_name='betaG')
df_polisy1_quality = pd.read_excel(polisy1, sheet_name='quality')

# %%
# Importation des tables pour STRASBOURG2
strasbourg2 = 'C:/Users/probl/Documents/Invivo/Baseline/STRASBOURG2/Baseline STRASBOURG2.xlsx'
df_strasbourg2_indiv = pd.read_excel(strasbourg2, sheet_name='nb_individus')
df_strasbourg2_malt_yield_r2 = pd.read_excel(strasbourg2, sheet_name='malt_yield_r2')
df_strasbourg2_malt_dry_yield = pd.read_excel(strasbourg2, sheet_name='malt_dry_yield')
df_strasbourg2_goods_weight = pd.read_excel(strasbourg2, sheet_name='goods_weight')
df_strasbourg2_goods_moisture = pd.read_excel(strasbourg2, sheet_name='goods_moisture')
df_strasbourg2_malt_moisture = pd.read_excel(strasbourg2, sheet_name='malt_moisture')
df_strasbourg2_electricity = pd.read_excel(strasbourg2, sheet_name='electricity')
df_strasbourg2_thermal = pd.read_excel(strasbourg2, sheet_name='thermal')
df_strasbourg2_FAN = pd.read_excel(strasbourg2, sheet_name='FAN')
df_strasbourg2_fria = pd.read_excel(strasbourg2, sheet_name='friabilite')
df_strasbourg2_color_EBC = pd.read_excel(strasbourg2, sheet_name='coloration_EBC')
df_strasbourg2_betaG = pd.read_excel(strasbourg2, sheet_name='betaG')
df_strasbourg2_quality = pd.read_excel(strasbourg2, sheet_name='quality')

# %%
# Importation des tables pour PROUVY1
prouvy1 = 'C:/Users/probl/Documents/Invivo/Baseline/prouvy1/Baseline PROUVY1.xlsx'
df_prouvy1_indiv = pd.read_excel(prouvy1, sheet_name='nb_individus')
df_prouvy1_malt_yield_r2 = pd.read_excel(prouvy1, sheet_name='malt_yield_r2')
df_prouvy1_malt_dry_yield = pd.read_excel(prouvy1, sheet_name='malt_dry_yield')
df_prouvy1_goods_weight = pd.read_excel(prouvy1, sheet_name='goods_weight')
df_prouvy1_goods_moisture = pd.read_excel(prouvy1, sheet_name='goods_moisture')
df_prouvy1_malt_moisture = pd.read_excel(prouvy1, sheet_name='malt_moisture')
df_prouvy1_electricity = pd.read_excel(prouvy1, sheet_name='electricity')
df_prouvy1_thermal = pd.read_excel(prouvy1, sheet_name='thermal')
df_prouvy1_FAN = pd.read_excel(prouvy1, sheet_name='FAN')
df_prouvy1_fria = pd.read_excel(prouvy1, sheet_name='friabilite')
df_prouvy1_color_EBC = pd.read_excel(prouvy1, sheet_name='coloration_EBC')
df_prouvy1_betaG = pd.read_excel(prouvy1, sheet_name='betaG')
df_prouvy1_quality = pd.read_excel(prouvy1, sheet_name='quality')

# %%
# Importation des tables pour BOLELEMI1
bolelemi1 = 'C:/Users/probl/Documents/Invivo/Baseline/BOLELEMI1/Baseline BOLELEMI1.xlsx'
df_bolelemi1_indiv = pd.read_excel(bolelemi1, sheet_name='nb_individus')
df_bolelemi1_malt_yield_r2 = pd.read_excel(bolelemi1, sheet_name='malt_yield_r2')
df_bolelemi1_malt_dry_yield = pd.read_excel(bolelemi1, sheet_name='malt_dry_yield')
df_bolelemi1_goods_weight = pd.read_excel(bolelemi1, sheet_name='goods_weight')
df_bolelemi1_goods_moisture = pd.read_excel(bolelemi1, sheet_name='goods_moisture')
df_bolelemi1_malt_moisture = pd.read_excel(bolelemi1, sheet_name='malt_moisture')
df_bolelemi1_electricity = pd.read_excel(bolelemi1, sheet_name='electricity')
df_bolelemi1_thermal = pd.read_excel(bolelemi1, sheet_name='thermal')
df_bolelemi1_FAN = pd.read_excel(bolelemi1, sheet_name='FAN')
df_bolelemi1_fria = pd.read_excel(bolelemi1, sheet_name='friabilite')
df_bolelemi1_color_EBC = pd.read_excel(bolelemi1, sheet_name='coloration_EBC')
df_bolelemi1_betaG = pd.read_excel(bolelemi1, sheet_name='betaG')
df_bolelemi1_quality = pd.read_excel(bolelemi1, sheet_name='quality')

# %%
# Liste des DataFrames
dataframes = [
        df_rouen1_indiv, df_rouen1_FAN, df_rouen1_fria, df_rouen1_color_EBC, df_rouen1_betaG, df_rouen1_quality,
    df_rouen1_malt_yield_r2, df_rouen1_malt_dry_yield, df_rouen1_goods_weight, df_rouen1_goods_moisture,
    df_rouen1_malt_moisture, df_rouen1_electricity, df_rouen1_thermal,
        df_nogent1_indiv, df_nogent1_FAN, df_nogent1_fria, df_nogent1_color_EBC, df_nogent1_betaG, df_nogent1_quality,
    df_nogent1_malt_yield_r2, df_nogent1_malt_dry_yield, df_nogent1_goods_weight, df_nogent1_goods_moisture,
    df_nogent1_malt_moisture, df_nogent1_electricity, df_nogent1_thermal,
        df_nogent2_indiv, df_nogent2_FAN, df_nogent2_fria, df_nogent2_color_EBC, df_nogent2_betaG, df_nogent2_quality,
    df_nogent2_malt_yield_r2, df_nogent2_malt_dry_yield, df_nogent2_goods_weight, df_nogent2_goods_moisture,
    df_nogent2_malt_moisture, df_nogent2_electricity, df_nogent2_thermal,
        df_polisy1_indiv, df_polisy1_FAN, df_polisy1_fria, df_polisy1_color_EBC, df_polisy1_betaG, df_polisy1_quality,
    df_polisy1_malt_yield_r2, df_polisy1_malt_dry_yield, df_polisy1_goods_weight, df_polisy1_goods_moisture,
    df_polisy1_malt_moisture, df_polisy1_electricity, df_polisy1_thermal,
        df_strasbourg2_indiv, df_strasbourg2_FAN, df_strasbourg2_fria, df_strasbourg2_color_EBC, df_strasbourg2_betaG, df_strasbourg2_quality,
    df_strasbourg2_malt_yield_r2, df_strasbourg2_malt_dry_yield, df_strasbourg2_goods_weight, df_strasbourg2_goods_moisture,
    df_strasbourg2_malt_moisture, df_strasbourg2_electricity, df_strasbourg2_thermal,
        df_prouvy1_indiv, df_prouvy1_FAN, df_prouvy1_fria, df_prouvy1_color_EBC, df_prouvy1_betaG, df_prouvy1_quality,
    df_prouvy1_malt_yield_r2, df_prouvy1_malt_dry_yield, df_prouvy1_goods_weight, df_prouvy1_goods_moisture,
    df_prouvy1_malt_moisture, df_prouvy1_electricity, df_prouvy1_thermal,
    df_bolelemi1_indiv, df_bolelemi1_FAN, df_bolelemi1_fria, df_bolelemi1_color_EBC, df_bolelemi1_betaG, df_bolelemi1_quality,
    df_bolelemi1_malt_yield_r2, df_bolelemi1_malt_dry_yield, df_bolelemi1_goods_weight, df_bolelemi1_goods_moisture,
    df_bolelemi1_malt_moisture, df_bolelemi1_electricity, df_bolelemi1_thermal
]



# Renommer la première colonne de chaque DataFrame en 'specification'
for df in dataframes:
    df.rename(columns={df.columns[0]: 'specification'}, inplace=True)

# %%
# Dépivoter les colonnes en utilisant la colonne 'specification'
df_rouen1_indiv = pd.melt(df_rouen1_indiv, id_vars=['specification'], var_name='Month', value_name='nb_individus')
df_rouen1_FAN = pd.melt(df_rouen1_FAN, id_vars=['specification'], var_name='Month', value_name='Baseline_FAN')
df_rouen1_fria = pd.melt(df_rouen1_fria, id_vars=['specification'], var_name='Month', value_name='Baseline_friabilite')
df_rouen1_color_EBC = pd.melt(df_rouen1_color_EBC, id_vars=['specification'], var_name='Month', value_name='Baseline_coloration_EBC')
df_rouen1_betaG = pd.melt(df_rouen1_betaG, id_vars=['specification'], var_name='Month', value_name='Baseline_betaG')
df_rouen1_quality = pd.melt(df_rouen1_quality, id_vars=['specification'], var_name='Month', value_name='Baseline_quality')
df_rouen1_malt_yield_r2 = pd.melt(df_rouen1_malt_yield_r2, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_yield_r2')
df_rouen1_malt_dry_yield = pd.melt(df_rouen1_malt_dry_yield, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_dry_yield')
df_rouen1_goods_weight = pd.melt(df_rouen1_goods_weight, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_weight')
df_rouen1_goods_moisture = pd.melt(df_rouen1_goods_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_moisture')
df_rouen1_malt_moisture = pd.melt(df_rouen1_malt_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_moisture')
df_rouen1_electricity = pd.melt(df_rouen1_electricity, id_vars=['specification'], var_name='Month', value_name='Baseline_electricity')
df_rouen1_thermal = pd.melt(df_rouen1_thermal, id_vars=['specification'], var_name='Month', value_name='Baseline_thermal')

# %%
# Dépivoter les colonnes en utilisant la colonne 'specification'
df_nogent1_indiv = pd.melt(df_nogent1_indiv, id_vars=['specification'], var_name='Month', value_name='nb_individus')
df_nogent1_FAN = pd.melt(df_nogent1_FAN, id_vars=['specification'], var_name='Month', value_name='Baseline_FAN')
df_nogent1_fria = pd.melt(df_nogent1_fria, id_vars=['specification'], var_name='Month', value_name='Baseline_friabilite')
df_nogent1_color_EBC = pd.melt(df_nogent1_color_EBC, id_vars=['specification'], var_name='Month', value_name='Baseline_coloration_EBC')
df_nogent1_betaG = pd.melt(df_nogent1_betaG, id_vars=['specification'], var_name='Month', value_name='Baseline_betaG')
df_nogent1_quality = pd.melt(df_nogent1_quality, id_vars=['specification'], var_name='Month', value_name='Baseline_quality')
df_nogent1_malt_yield_r2 = pd.melt(df_nogent1_malt_yield_r2, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_yield_r2')
df_nogent1_malt_dry_yield = pd.melt(df_nogent1_malt_dry_yield, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_dry_yield')
df_nogent1_goods_weight = pd.melt(df_nogent1_goods_weight, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_weight')
df_nogent1_goods_moisture = pd.melt(df_nogent1_goods_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_moisture')
df_nogent1_malt_moisture = pd.melt(df_nogent1_malt_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_moisture')
df_nogent1_electricity = pd.melt(df_nogent1_electricity, id_vars=['specification'], var_name='Month', value_name='Baseline_electricity')
df_nogent1_thermal = pd.melt(df_nogent1_thermal, id_vars=['specification'], var_name='Month', value_name='Baseline_thermal')

# %%
# Dépivoter les colonnes en utilisant la colonne 'specification'
df_nogent2_indiv = pd.melt(df_nogent2_indiv, id_vars=['specification'], var_name='Month', value_name='nb_individus')
df_nogent2_FAN = pd.melt(df_nogent2_FAN, id_vars=['specification'], var_name='Month', value_name='Baseline_FAN')
df_nogent2_fria = pd.melt(df_nogent2_fria, id_vars=['specification'], var_name='Month', value_name='Baseline_friabilite')
df_nogent2_color_EBC = pd.melt(df_nogent2_color_EBC, id_vars=['specification'], var_name='Month', value_name='Baseline_coloration_EBC')
df_nogent2_betaG = pd.melt(df_nogent2_betaG, id_vars=['specification'], var_name='Month', value_name='Baseline_betaG')
df_nogent2_quality = pd.melt(df_nogent2_quality, id_vars=['specification'], var_name='Month', value_name='Baseline_quality')
df_nogent2_malt_yield_r2 = pd.melt(df_nogent2_malt_yield_r2, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_yield_r2')
df_nogent2_malt_dry_yield = pd.melt(df_nogent2_malt_dry_yield, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_dry_yield')
df_nogent2_goods_weight = pd.melt(df_nogent2_goods_weight, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_weight')
df_nogent2_goods_moisture = pd.melt(df_nogent2_goods_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_moisture')
df_nogent2_malt_moisture = pd.melt(df_nogent2_malt_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_moisture')
df_nogent2_electricity = pd.melt(df_nogent2_electricity, id_vars=['specification'], var_name='Month', value_name='Baseline_electricity')
df_nogent2_thermal = pd.melt(df_nogent2_thermal, id_vars=['specification'], var_name='Month', value_name='Baseline_thermal')

# %%
# Dépivoter les colonnes en utilisant la colonne 'specification'
df_polisy1_indiv = pd.melt(df_polisy1_indiv, id_vars=['specification'], var_name='Month', value_name='nb_individus')
df_polisy1_FAN = pd.melt(df_polisy1_FAN, id_vars=['specification'], var_name='Month', value_name='Baseline_FAN')
df_polisy1_fria = pd.melt(df_polisy1_fria, id_vars=['specification'], var_name='Month', value_name='Baseline_friabilite')
df_polisy1_color_EBC = pd.melt(df_polisy1_color_EBC, id_vars=['specification'], var_name='Month', value_name='Baseline_coloration_EBC')
df_polisy1_betaG = pd.melt(df_polisy1_betaG, id_vars=['specification'], var_name='Month', value_name='Baseline_betaG')
df_polisy1_quality = pd.melt(df_polisy1_quality, id_vars=['specification'], var_name='Month', value_name='Baseline_quality')
df_polisy1_malt_yield_r2 = pd.melt(df_polisy1_malt_yield_r2, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_yield_r2')
df_polisy1_malt_dry_yield = pd.melt(df_polisy1_malt_dry_yield, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_dry_yield')
df_polisy1_goods_weight = pd.melt(df_polisy1_goods_weight, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_weight')
df_polisy1_goods_moisture = pd.melt(df_polisy1_goods_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_moisture')
df_polisy1_malt_moisture = pd.melt(df_polisy1_malt_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_moisture')
df_polisy1_electricity = pd.melt(df_polisy1_electricity, id_vars=['specification'], var_name='Month', value_name='Baseline_electricity')
df_polisy1_thermal = pd.melt(df_polisy1_thermal, id_vars=['specification'], var_name='Month', value_name='Baseline_thermal')

# %%
# Dépivoter les colonnes en utilisant la colonne 'specification'
df_strasbourg2_indiv = pd.melt(df_strasbourg2_indiv, id_vars=['specification'], var_name='Month', value_name='nb_individus')
df_strasbourg2_FAN = pd.melt(df_strasbourg2_FAN, id_vars=['specification'], var_name='Month', value_name='Baseline_FAN')
df_strasbourg2_fria = pd.melt(df_strasbourg2_fria, id_vars=['specification'], var_name='Month', value_name='Baseline_friabilite')
df_strasbourg2_color_EBC = pd.melt(df_strasbourg2_color_EBC, id_vars=['specification'], var_name='Month', value_name='Baseline_coloration_EBC')
df_strasbourg2_betaG = pd.melt(df_strasbourg2_betaG, id_vars=['specification'], var_name='Month', value_name='Baseline_betaG')
df_strasbourg2_quality = pd.melt(df_strasbourg2_quality, id_vars=['specification'], var_name='Month', value_name='Baseline_quality')
df_strasbourg2_malt_yield_r2 = pd.melt(df_strasbourg2_malt_yield_r2, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_yield_r2')
df_strasbourg2_malt_dry_yield = pd.melt(df_strasbourg2_malt_dry_yield, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_dry_yield')
df_strasbourg2_goods_weight = pd.melt(df_strasbourg2_goods_weight, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_weight')
df_strasbourg2_goods_moisture = pd.melt(df_strasbourg2_goods_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_moisture')
df_strasbourg2_malt_moisture = pd.melt(df_strasbourg2_malt_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_moisture')
df_strasbourg2_electricity = pd.melt(df_strasbourg2_electricity, id_vars=['specification'], var_name='Month', value_name='Baseline_electricity')
df_strasbourg2_thermal = pd.melt(df_strasbourg2_thermal, id_vars=['specification'], var_name='Month', value_name='Baseline_thermal')

# %%
# Dépivoter les colonnes en utilisant la colonne 'specification'
df_prouvy1_indiv = pd.melt(df_prouvy1_indiv, id_vars=['specification'], var_name='Month', value_name='nb_individus')
df_prouvy1_FAN = pd.melt(df_prouvy1_FAN, id_vars=['specification'], var_name='Month', value_name='Baseline_FAN')
df_prouvy1_fria = pd.melt(df_prouvy1_fria, id_vars=['specification'], var_name='Month', value_name='Baseline_friabilite')
df_prouvy1_color_EBC = pd.melt(df_prouvy1_color_EBC, id_vars=['specification'], var_name='Month', value_name='Baseline_coloration_EBC')
df_prouvy1_betaG = pd.melt(df_prouvy1_betaG, id_vars=['specification'], var_name='Month', value_name='Baseline_betaG')
df_prouvy1_quality = pd.melt(df_prouvy1_quality, id_vars=['specification'], var_name='Month', value_name='Baseline_quality')
df_prouvy1_malt_yield_r2 = pd.melt(df_prouvy1_malt_yield_r2, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_yield_r2')
df_prouvy1_malt_dry_yield = pd.melt(df_prouvy1_malt_dry_yield, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_dry_yield')
df_prouvy1_goods_weight = pd.melt(df_prouvy1_goods_weight, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_weight')
df_prouvy1_goods_moisture = pd.melt(df_prouvy1_goods_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_moisture')
df_prouvy1_malt_moisture = pd.melt(df_prouvy1_malt_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_moisture')
df_prouvy1_electricity = pd.melt(df_prouvy1_electricity, id_vars=['specification'], var_name='Month', value_name='Baseline_electricity')
df_prouvy1_thermal = pd.melt(df_prouvy1_thermal, id_vars=['specification'], var_name='Month', value_name='Baseline_thermal')

# %%
# Dépivoter les colonnes en utilisant la colonne 'specification'
df_bolelemi1_indiv = pd.melt(df_bolelemi1_indiv, id_vars=['specification'], var_name='Month', value_name='nb_individus')
df_bolelemi1_FAN = pd.melt(df_bolelemi1_FAN, id_vars=['specification'], var_name='Month', value_name='Baseline_FAN')
df_bolelemi1_fria = pd.melt(df_bolelemi1_fria, id_vars=['specification'], var_name='Month', value_name='Baseline_friabilite')
df_bolelemi1_color_EBC = pd.melt(df_bolelemi1_color_EBC, id_vars=['specification'], var_name='Month', value_name='Baseline_coloration_EBC')
df_bolelemi1_betaG = pd.melt(df_bolelemi1_betaG, id_vars=['specification'], var_name='Month', value_name='Baseline_betaG')
df_bolelemi1_quality = pd.melt(df_bolelemi1_quality, id_vars=['specification'], var_name='Month', value_name='Baseline_quality')
df_bolelemi1_malt_yield_r2 = pd.melt(df_bolelemi1_malt_yield_r2, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_yield_r2')
df_bolelemi1_malt_dry_yield = pd.melt(df_bolelemi1_malt_dry_yield, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_dry_yield')
df_bolelemi1_goods_weight = pd.melt(df_bolelemi1_goods_weight, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_weight')
df_bolelemi1_goods_moisture = pd.melt(df_bolelemi1_goods_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_goods_moisture')
df_bolelemi1_malt_moisture = pd.melt(df_bolelemi1_malt_moisture, id_vars=['specification'], var_name='Month', value_name='Baseline_malt_moisture')
df_bolelemi1_electricity = pd.melt(df_bolelemi1_electricity, id_vars=['specification'], var_name='Month', value_name='Baseline_electricity')
df_bolelemi1_thermal = pd.melt(df_bolelemi1_thermal, id_vars=['specification'], var_name='Month', value_name='Baseline_thermal')

# %%
# Ajout colonne id_site et clé de jointure
dataframes_rouen1 = [
    df_rouen1_indiv, df_rouen1_FAN, df_rouen1_fria, df_rouen1_color_EBC, df_rouen1_betaG, df_rouen1_quality,
    df_rouen1_malt_yield_r2, df_rouen1_malt_dry_yield, df_rouen1_goods_weight, df_rouen1_goods_moisture,
    df_rouen1_malt_moisture, df_rouen1_electricity, df_rouen1_thermal
]

for df in dataframes_rouen1:
    df['id_site'] = 1
    
for df in dataframes_rouen1:
    df['key'] = df['specification'] + df['Month'].astype(str)

# %%
# Ajout colonne id_site et clé de jointure
dataframes_polisy1 = [
    df_polisy1_indiv, df_polisy1_FAN, df_polisy1_fria, df_polisy1_color_EBC, df_polisy1_betaG, df_polisy1_quality,
    df_polisy1_malt_yield_r2, df_polisy1_malt_dry_yield, df_polisy1_goods_weight, df_polisy1_goods_moisture,
    df_polisy1_malt_moisture, df_polisy1_electricity, df_polisy1_thermal
]

for df in dataframes_polisy1:
    df['id_site'] = 2
    
for df in dataframes_polisy1:
    df['key'] = df['specification'] + df['Month'].astype(str)

# %%
# Ajout colonne id_site et clé de jointure
dataframes_nogent2 = [
    df_nogent2_indiv, df_nogent2_FAN, df_nogent2_fria, df_nogent2_color_EBC, df_nogent2_betaG, df_nogent2_quality,
    df_nogent2_malt_yield_r2, df_nogent2_malt_dry_yield, df_nogent2_goods_weight, df_nogent2_goods_moisture,
    df_nogent2_malt_moisture, df_nogent2_electricity, df_nogent2_thermal
]

for df in dataframes_nogent2:
    df['id_site'] = 3
    
for df in dataframes_nogent2:
    df['key'] = df['specification'] + df['Month'].astype(str)

# %%
# Ajout colonne id_site et clé de jointure
dataframes_prouvy1 = [
    df_prouvy1_indiv, df_prouvy1_FAN, df_prouvy1_fria, df_prouvy1_color_EBC, df_prouvy1_betaG, df_prouvy1_quality,
    df_prouvy1_malt_yield_r2, df_prouvy1_malt_dry_yield, df_prouvy1_goods_weight, df_prouvy1_goods_moisture,
    df_prouvy1_malt_moisture, df_prouvy1_electricity, df_prouvy1_thermal
]

for df in dataframes_prouvy1:
    df['id_site'] = 4
    
for df in dataframes_prouvy1:
    df['key'] = df['specification'] + df['Month'].astype(str)

# %%
# Ajout colonne id_site et clé de jointure
dataframes_bolelemi1 = [
    df_bolelemi1_indiv, df_bolelemi1_FAN, df_bolelemi1_fria, df_bolelemi1_color_EBC, df_bolelemi1_betaG, df_bolelemi1_quality,
    df_bolelemi1_malt_yield_r2, df_bolelemi1_malt_dry_yield, df_bolelemi1_goods_weight, df_bolelemi1_goods_moisture,
    df_bolelemi1_malt_moisture, df_bolelemi1_electricity, df_bolelemi1_thermal
]

# id_plant_production_line de BOLELEMI1 dans plants_production_lines (relevé en base).
id_site_bolelemi1 = 15

for df in dataframes_bolelemi1:
    df['id_site'] = id_site_bolelemi1

for df in dataframes_bolelemi1:
    df['key'] = df['specification'] + df['Month'].astype(str)

# %%
# Ajout colonne id_site et clé de jointure
dataframes_strasbourg2 = [
    df_strasbourg2_indiv, df_strasbourg2_FAN, df_strasbourg2_fria, df_strasbourg2_color_EBC, df_strasbourg2_betaG, df_strasbourg2_quality,
    df_strasbourg2_malt_yield_r2, df_strasbourg2_malt_dry_yield, df_strasbourg2_goods_weight, df_strasbourg2_goods_moisture,
    df_strasbourg2_malt_moisture, df_strasbourg2_electricity, df_strasbourg2_thermal
]

for df in dataframes_strasbourg2:
    df['id_site'] = 5
    
for df in dataframes_strasbourg2:
    df['key'] = df['specification'] + df['Month'].astype(str)

# %%
# Ajout colonne id_site et clé de jointure
dataframes_nogent1 = [
    df_nogent1_indiv, df_nogent1_FAN, df_nogent1_fria, df_nogent1_color_EBC, df_nogent1_betaG, df_nogent1_quality,
    df_nogent1_malt_yield_r2, df_nogent1_malt_dry_yield, df_nogent1_goods_weight, df_nogent1_goods_moisture,
    df_nogent1_malt_moisture, df_nogent1_electricity, df_nogent1_thermal
]

for df in dataframes_nogent1:
    df['id_site'] = 6
    
for df in dataframes_nogent1:
    df['key'] = df['specification'] + df['Month'].astype(str)

# %%
df_rouen1 = df_rouen1_indiv.merge(df_rouen1_malt_yield_r2[['key', 'Baseline_malt_yield_r2']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_malt_dry_yield[['key', 'Baseline_malt_dry_yield']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_goods_weight[['key', 'Baseline_goods_weight']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_goods_moisture[['key', 'Baseline_goods_moisture']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_malt_moisture[['key', 'Baseline_malt_moisture']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_electricity[['key', 'Baseline_electricity']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_thermal[['key', 'Baseline_thermal']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_FAN[['key', 'Baseline_FAN']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_fria[['key', 'Baseline_friabilite']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_color_EBC[['key', 'Baseline_coloration_EBC']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_betaG[['key', 'Baseline_betaG']], on='key', how='left')
df_rouen1 = df_rouen1.merge(df_rouen1_quality[['key', 'Baseline_quality']], on='key', how='left')

# %%
df_nogent1 = df_nogent1_indiv.merge(df_nogent1_malt_yield_r2[['key', 'Baseline_malt_yield_r2']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_malt_dry_yield[['key', 'Baseline_malt_dry_yield']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_goods_weight[['key', 'Baseline_goods_weight']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_goods_moisture[['key', 'Baseline_goods_moisture']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_malt_moisture[['key', 'Baseline_malt_moisture']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_electricity[['key', 'Baseline_electricity']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_thermal[['key', 'Baseline_thermal']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_FAN[['key', 'Baseline_FAN']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_fria[['key', 'Baseline_friabilite']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_color_EBC[['key', 'Baseline_coloration_EBC']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_betaG[['key', 'Baseline_betaG']], on='key', how='left')
df_nogent1 = df_nogent1.merge(df_nogent1_quality[['key', 'Baseline_quality']], on='key', how='left')

# %%
df_nogent2 = df_nogent2_indiv.merge(df_nogent2_malt_yield_r2[['key', 'Baseline_malt_yield_r2']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_malt_dry_yield[['key', 'Baseline_malt_dry_yield']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_goods_weight[['key', 'Baseline_goods_weight']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_goods_moisture[['key', 'Baseline_goods_moisture']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_malt_moisture[['key', 'Baseline_malt_moisture']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_electricity[['key', 'Baseline_electricity']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_thermal[['key', 'Baseline_thermal']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_FAN[['key', 'Baseline_FAN']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_fria[['key', 'Baseline_friabilite']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_color_EBC[['key', 'Baseline_coloration_EBC']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_betaG[['key', 'Baseline_betaG']], on='key', how='left')
df_nogent2 = df_nogent2.merge(df_nogent2_quality[['key', 'Baseline_quality']], on='key', how='left')

# %%
df_polisy1 = df_polisy1_indiv.merge(df_polisy1_malt_yield_r2[['key', 'Baseline_malt_yield_r2']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_malt_dry_yield[['key', 'Baseline_malt_dry_yield']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_goods_weight[['key', 'Baseline_goods_weight']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_goods_moisture[['key', 'Baseline_goods_moisture']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_malt_moisture[['key', 'Baseline_malt_moisture']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_electricity[['key', 'Baseline_electricity']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_thermal[['key', 'Baseline_thermal']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_FAN[['key', 'Baseline_FAN']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_fria[['key', 'Baseline_friabilite']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_color_EBC[['key', 'Baseline_coloration_EBC']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_betaG[['key', 'Baseline_betaG']], on='key', how='left')
df_polisy1 = df_polisy1.merge(df_polisy1_quality[['key', 'Baseline_quality']], on='key', how='left')

# %%
df_strasbourg2 = df_strasbourg2_indiv.merge(df_strasbourg2_malt_yield_r2[['key', 'Baseline_malt_yield_r2']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_malt_dry_yield[['key', 'Baseline_malt_dry_yield']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_goods_weight[['key', 'Baseline_goods_weight']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_goods_moisture[['key', 'Baseline_goods_moisture']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_malt_moisture[['key', 'Baseline_malt_moisture']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_electricity[['key', 'Baseline_electricity']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_thermal[['key', 'Baseline_thermal']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_FAN[['key', 'Baseline_FAN']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_fria[['key', 'Baseline_friabilite']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_color_EBC[['key', 'Baseline_coloration_EBC']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_betaG[['key', 'Baseline_betaG']], on='key', how='left')
df_strasbourg2 = df_strasbourg2.merge(df_strasbourg2_quality[['key', 'Baseline_quality']], on='key', how='left')

# %%
df_prouvy1 = df_prouvy1_indiv.merge(df_prouvy1_malt_yield_r2[['key', 'Baseline_malt_yield_r2']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_malt_dry_yield[['key', 'Baseline_malt_dry_yield']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_goods_weight[['key', 'Baseline_goods_weight']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_goods_moisture[['key', 'Baseline_goods_moisture']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_malt_moisture[['key', 'Baseline_malt_moisture']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_electricity[['key', 'Baseline_electricity']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_thermal[['key', 'Baseline_thermal']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_FAN[['key', 'Baseline_FAN']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_fria[['key', 'Baseline_friabilite']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_color_EBC[['key', 'Baseline_coloration_EBC']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_betaG[['key', 'Baseline_betaG']], on='key', how='left')
df_prouvy1 = df_prouvy1.merge(df_prouvy1_quality[['key', 'Baseline_quality']], on='key', how='left')

# %%
df_bolelemi1 = df_bolelemi1_indiv.merge(df_bolelemi1_malt_yield_r2[['key', 'Baseline_malt_yield_r2']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_malt_dry_yield[['key', 'Baseline_malt_dry_yield']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_goods_weight[['key', 'Baseline_goods_weight']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_goods_moisture[['key', 'Baseline_goods_moisture']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_malt_moisture[['key', 'Baseline_malt_moisture']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_electricity[['key', 'Baseline_electricity']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_thermal[['key', 'Baseline_thermal']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_FAN[['key', 'Baseline_FAN']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_fria[['key', 'Baseline_friabilite']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_color_EBC[['key', 'Baseline_coloration_EBC']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_betaG[['key', 'Baseline_betaG']], on='key', how='left')
df_bolelemi1 = df_bolelemi1.merge(df_bolelemi1_quality[['key', 'Baseline_quality']], on='key', how='left')

# %%
df_baseline = pd.concat([df_rouen1, df_nogent1, df_nogent2, df_polisy1, df_strasbourg2, df_prouvy1, df_bolelemi1], ignore_index=True)
df_baseline.drop(columns='key', inplace=True)

# %%
# Importation du fichier avec les noms des sites
df_plants = pd.read_excel('C:/Users/probl/Documents/Invivo/Baseline/DIM_SITE.xlsx')

# %%
df_baseline = df_baseline.merge(df_plants[['id_site_production', 'site_production']], left_on='id_site', right_on='id_site_production', how='left')
df_baseline.drop(columns='id_site_production', inplace=True)
df_baseline = df_baseline.rename(columns={'site_production': 'site'})

# %%
# Importation du fichier avec les numéros des cahiers des charges
df_cdc = pd.read_csv('C:/Users/probl/Documents/Invivo/Baseline/requirement_specifications.csv', delimiter=',')

# %%
df_baseline = df_baseline.merge(df_cdc[['name', 'id_requirement_specification']], left_on='specification', right_on='name', how='left')
df_baseline.drop(columns='name', inplace=True)
df_baseline = df_baseline.rename(columns={'id_requirement_specification': 'id_specification'})
df_baseline['id_specification'] = df_baseline['id_specification'].fillna(99).astype(int)

# %%
# Importation du fichier avec les espèces et variétés
df_specy = pd.read_excel('C:/Users/probl/Documents/Invivo/Baseline/specy_variete.xlsx')

# %%
df_baseline['key'] = df_baseline['id_site'].astype(str) + df_baseline['specification']

df_specy['key'] = df_specy['id_plant'].astype(str) + df_specy['specifications']

df_baseline = df_baseline.merge(df_specy[['key', 'goods_specy', 'goods_variety']], on='key', how='left')
df_baseline.drop(columns='key', inplace=True)

# %%
df_baseline = df_baseline[[
    'id_specification',
    'specification',
    'id_site',
    'site',
    'Month',
    'goods_specy',
    'goods_variety',
    'nb_individus',
    'Baseline_malt_yield_r2',
    'Baseline_malt_dry_yield',
    'Baseline_goods_weight',
    'Baseline_goods_moisture',
    'Baseline_malt_moisture',
    'Baseline_electricity',
    'Baseline_thermal',
    'Baseline_FAN',
    'Baseline_friabilite',
    'Baseline_coloration_EBC',
    'Baseline_betaG',
    'Baseline_quality'
]]

# %%
# Ajout des colonnes nécessaires à Databricks
df_baseline['created_at'] = ""
df_baseline['updated_at'] = ""
df_baseline['deleted_at'] = ""

# %%
df_baseline.to_csv(r'C:\Users\probl\Documents\Invivo\Baseline\Baseline.csv', index=False)

# %%
import winsound
winsound.Beep(1000, 1000)
